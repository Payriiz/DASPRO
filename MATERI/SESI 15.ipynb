# %%
import pandas as pd
import numpy as np
#library visual -> Matplotlib & Seaborn
import matplotlib.pyplot as plt
#np.random.seed(42) #Agar saat sesudah di random, tidak di acak lagi.
bulan = ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Des']
minggu1 = np.random.randint(200000,1000001,12)
minggu2 = np.random.randint(200000,1000001,12)
minggu3 = np.random.randint(200000,1000001,12)
minggu4 = np.random.randint(200000,1000001,12)

data = {
    'Bulan' : bulan,
    'Minggu_1' : minggu1,
    'Minggu_2' : minggu2,
    'Minggu_3' : minggu3,
    'Minggu_4' : minggu4,
}    #yang dipanggil itu yang dikiri, yang kanan itu VALUE

df = pd.DataFrame(data)

df ['Total Pengeluaran'] = df[['Minggu_1','Minggu_2','Minggu_3','Minggu_4']].sum(axis=1)

df.head(12)
# Out:
#    Bulan  Minggu_1  Minggu_2  Minggu_3  Minggu_4  Total Pengeluaran
# 0    Jan    848531    541097    764685    474329            2628642
# 1    Feb    451995    515139    982038    919064            2868236
# 2    Mar    878843    371829    553531    942139            2746342
# 3    Apr    772843    471836    463160    632315            2340154
# 4    May    456508    638974    779879    716588            2591949
# 5    Jun    306530    402283    420884    436584            1566281
# 6    Jul    804365    396769    223247    762332            2186713
# 7    Aug    660337    761353    224300    576896            2222886
# 8    Sep    924839    423165    667281    248984            2264269
# 9    Oct    659773    823587    807086    502918            2793364
# 10   Nov    408261    735822    733556    464712            2342351
# 11   Des    964469    687879    548951    320151            2521450

# %%
#Diagram Bar -> Proses Perbandingan
#Buatkan Canvas
plt.figure(figsize=(12,6)) #width,height -> inch
plt.bar(df['Bulan'], df['Total Pengeluaran'], color = ['#FF00FF', '#FFC0CB', '#FF00FF', '#FFC0CB'])
plt.title("PENGELUARAN MAHASISWA PERBULAN")
plt.xticks(rotation=-45) #memiringkan yang dibawah
plt.grid(axis='y') #agar ada garis ke kanan nya
plt.show()

#solusi agar bawahnya tidak menumpuk
#plt.xticks(rotation=-45)
#plt.tight_layout
#plt.grid(axis='y')

# %%
plt.figure(figsize=(12,4))

for minggu in ['Minggu_1','Minggu_2','Minggu_3','Minggu_4',]:
    plt.plot(df['Bulan'],df[minggu],marker='o',label=minggu)

plt.title("PENGELUARAN MAHASISWA PERMINGGU")
plt.xlabel("Bulan")
plt.ylabel("Tren Pengeluaran Mahasiswa")
plt.legend()
plt.grid(True)
plt.show()

# %%
#Pie Diagram
plt.figure(figsize=(5,5))
plt.pie(df['Total Pengeluaran'],labels=df['Bulan'],autopct='%1.1f%%')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Regresi Linear
#Open Source -> scikit -> sklearn
from sklearn.linear_model import LinearRegression

df['Bulan_Angka'] = np.arange(1,13)

x = df[['Bulan_Angka']]
y = df['Total Pengeluaran']

model = LinearRegression()
model.fit(x,y)

bulan_13 = model.predict([[13]])[0]

print(f"Prediksi Pengeluaran Mahasiswa Januari 2026:{bulan_13:,.0f}")
# Out:
# Prediksi Pengeluaran Mahasiswa Januari 2026:2,276,149
# D:\ANACONDA\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
